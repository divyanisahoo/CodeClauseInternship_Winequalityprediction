# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

#for ML
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb
from sklearn.metrics import accuracy_score,f1_score,classification_report,confusion_matrix

import warnings
warnings.filterwarnings('ignore')
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv("C:\\Users\\Pavillion\\Data\\WineQT.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.describe().T.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_56adb_row0_col0, #T_56adb_row1_col0, #T_56adb_row1_col7, #T_56adb_row2_col0, #T_56adb_row2_col3, #T_56adb_row2_col4, #T_56adb_row2_col7, #T_56adb_row3_col0, #T_56adb_row4_col0, #T_56adb_row4_col1, #T_56adb_row4_col2, #T_56adb_row4_col3, #T_56adb_row4_col4, #T_56adb_row4_col5, #T_56adb_row4_col6, #T_56adb_row4_col7, #T_56adb_row5_col0, #T_56adb_row6_col0, #T_56adb_row7_col0, #T_56adb_row7_col2, #T_56adb_row7_col7, #T_56adb_row8_col0, #T_56adb_row9_col0, #T_56adb_row10_col0, #T_56adb_row11_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_56adb_row0_col1 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_56adb_row0_col2, #T_56adb_row0_col7, #T_56adb_row3_col1, #T_56adb_row3_col7, #T_56adb_row8_col6 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_56adb_row0_col3 {
#   background-color: #60ba6c;
#   color: #f1f1f1;
# }
# #T_56adb_row0_col4 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_56adb_row0_col5 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_56adb_row0_col6 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_56adb_row1_col1, #T_56adb_row1_col2, #T_56adb_row1_col6, #T_56adb_row2_col1, #T_56adb_row2_col2, #T_56adb_row2_col5, #T_56adb_row2_col6, #T_56adb_row8_col2, #T_56adb_row9_col2, #T_56adb_row9_col6, #T_56adb_row9_col7 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_56adb_row1_col3, #T_56adb_row1_col4, #T_56adb_row1_col5, #T_56adb_row7_col6, #T_56adb_row8_col7, #T_56adb_row9_col1, #T_56adb_row9_col5 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_56adb_row3_col2, #T_56adb_row3_col6, #T_56adb_row7_col4, #T_56adb_row9_col3 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_56adb_row3_col3 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_56adb_row3_col4, #T_56adb_row8_col5 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_56adb_row3_col5 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_56adb_row5_col1 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_56adb_row5_col2 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_56adb_row5_col3, #T_56adb_row7_col3 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_56adb_row5_col4 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# #T_56adb_row5_col5 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_56adb_row5_col6 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_56adb_row5_col7 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_56adb_row6_col1, #T_56adb_row6_col2, #T_56adb_row6_col4, #T_56adb_row6_col5, #T_56adb_row6_col6, #T_56adb_row6_col7, #T_56adb_row10_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_56adb_row6_col3 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_56adb_row7_col1, #T_56adb_row9_col4 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_56adb_row7_col5, #T_56adb_row11_col2, #T_56adb_row11_col7 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_56adb_row8_col1 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_56adb_row8_col3 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_56adb_row8_col4 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_56adb_row10_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_56adb_row10_col2 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_56adb_row10_col4 {
#   background-color: #86cc85;
#   color: #000000;
# }
# #T_56adb_row10_col5 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_56adb_row10_col6 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_56adb_row10_col7 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_56adb_row11_col1 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_56adb_row11_col3 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_56adb_row11_col4 {
#   background-color: #cbeac4;
#   color: #000000;
# }
# #T_56adb_row11_col5 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_56adb_row11_col6 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# </style>
# <table id="T_56adb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56adb_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_56adb_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_56adb_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_56adb_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_56adb_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_56adb_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_56adb_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_56adb_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56adb_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_56adb_row0_col0" class="data row0 col0" >1143.000000</td>
#       <td id="T_56adb_row0_col1" class="data row0 col1" >8.311111</td>
#       <td id="T_56adb_row0_col2" class="data row0 col2" >1.747595</td>
#       <td id="T_56adb_row0_col3" class="data row0 col3" >4.600000</td>
#       <td id="T_56adb_row0_col4" class="data row0 col4" >7.100000</td>
#       <td id="T_56adb_row0_col5" class="data row0 col5" >7.900000</td>
#       <td id="T_56adb_row0_col6" class="data row0 col6" >9.100000</td>
#       <td id="T_56adb_row0_col7" class="data row0 col7" >15.900000</td>
#     </tr>
#     <tr>
#       <th id="T_56adb_level0_row1" class="row_heading level0 row1" >volatile acidity</th>
#       <td id="T_56adb_row1_col0" class="data row1 col0" >1143.000000</td>
#       <td id="T_56adb_row1_col1" class="data row1 col1" >0.531339</td>
#       <td id="T_56adb_row1_col2" class="data row1 col2" >0.179633</td>
#       <td id="T_56adb_row1_col3" class="data row1 col3" >0.120000</td>
#       <td id="T_56adb_row1_col4" class="data row1 col4" >0.392500</td>
#       <td id="T_56adb_row1_col5" class="data row1 col5" >0.520000</td>
#       <td id="T_56adb_row1_col6" class="data row1 col6" >0.640000</td>
#       <td id="T_56adb_row1_col7" class="data row1 col7" >1.580000</td>
#     </tr>
#     <tr>
#       <th id="T_56adb_level0_row2" class="row_heading level0 row2" >citric acid</th>
#       <td id="T_56adb_row2_col0" class="data row2 col0" >1143.000000</td>
#       <td id="T_56adb_row2_col1" class="data row2 col1" >0.268364</td>
#       <td id="T_56adb_row2_col2" class="data row2 col2" >0.196686</td>
#       <td id="T_56adb_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_56adb_row2_col4" class="data row2 col4" >0.090000</td>
#       <td id="T_56adb_row2_col5" class="data row2 col5" >0.250000</td>
#       <td id="T_56adb_row2_col6" class="data row2 col6" >0.420000</td>
#       <td id="T_56adb_row2_col7" class="data row2 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_56adb_level0_row3" class="row_heading level0 row3" >residual sugar</th>
#       <td id="T_56adb_row3_col0" class="data row3 col0" >1143.000000</td>
#       <td id="T_56adb_row3_col1" class="data row3 col1" >2.532152</td>
#       <td id="T_56adb_row3_col2" class="data row3 col2" >1.355917</td>
#       <td id="T_56adb_row3_col3" class="data row3 col3" >0.900000</td>
#       <td id="T_56adb_row3_col4" class="data row3 col4" >1.900000</td>
#       <td id="T_56adb_row3_col5" class="data row3 col5" >2.200000</td>
#       <td id="T_56adb_row3_col6" class="data row3 col6" >2.600000</td>
#       <td id="T_56adb_row3_col7" class="data row3 col7" >15.500000</td>
#     </tr>
#     <tr>
#       <th id="T_56adb_level0_row4" class="row_heading level0 row4" >chlorides</th>
#       <td id="T_56adb_row4_col0" class="data row4 col0" >1143.000000</td>
#       <td id="T_56adb_row4_col1" class="data row4 col1" >0.086933</td>
#       <td id="T_56adb_row4_col2" class="data row4 col2" >0.047267</td>
#       <td id="T_56adb_row4_col3" class="data row4 col3" >0.012000</td>
#       <td id="T_56adb_row4_col4" class="data row4 col4" >0.070000</td>
#       <td id="T_56adb_row4_col5" class="data row4 col5" >0.079000</td>
#       <td id="T_56adb_row4_col6" class="data row4 col6" >0.090000</td>
#       <td id="T_56adb_row4_col7" class="data row4 col7" >0.611000</td>
#     </tr>
#     <tr>

# %% [markdown]
# ## EDA

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='quality',data=df)
plt.show()

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.171831   0.107889            -0.164831
# volatile acidity           -0.005751   0.056336            -0.001962
# citric acid                 0.175815   0.245312            -0.057589
# residual sugar              1.000000   0.070863             0.165339
# chlorides                   0.070863   1.000000             0.015280
# free sulfur dioxide         0.165339   0.015280             1.000000
# total sulfur dioxide        0.190790   0.048163             0.661093
# density                     0.380147   0.208901            -0.054150
# pH                         -0.116959  -0.277759             0.072804
# sulphates                   0.017475   0.374784             0.034445
# alcohol                     0.058421  -0.229917            -0.047095
# quality                     0.022002  -0.124085            -0.063260
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.110628  0.681501 -0.685163   0.174592
# volatile acidity                  0.077748  0.016512  0.221492  -0.276079
# citric acid                       0.036871  0.375243 -0.546339   0.331232
# residual sugar                    0.190790  0.380147 -0.116959   0.017475
# chlorides                         0.048163  0.208901 -0.277759   0.374784
# free sulfur dioxide               0.661093 -0.054150  0.072804   0.034445
# total sulfur dioxide              1.000000  0.050175 -0.059126   0.026894
# density                           0.050175  1.000000 -0.352775   0.143139
# pH                               -0.059126 -0.352775  1.000000  -0.185499
# sulphates                         0.026894  0.143139 -0.185499   1.000000
# alcohol                          -0.188165 -0.494727  0.225322   0.094421
# quality                          -0.183339 -0.175208 -0.052453   0.257710
#
#                        alcohol   quality
# fixed acidity        -0.075055  0.121970
# volatile acidity     -0.203909 -0.407394
# citric acid           0.106250  0.240821
# residual sugar        0.058421  0.022002
# chlorides            -0.229917 -0.124085
# free sulfur dioxide  -0.047095 -0.063260
# total sulfur dioxide -0.188165 -0.183339
# density              -0.494727 -0.175208
# pH                    0.225322 -0.052453
# sulphates             0.094421  0.257710
# alcohol               1.000000  0.484866
# quality               0.484866  1.000000

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# ###  Plot b/w total sulphur dioxide and free sulphur dioxide

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x='total sulfur dioxide',y='free sulfur dioxide',data=df)
plt.show()

# %% [markdown]
# ### Quality of wine varies b/w 3-8,and the below plot give information about how the quality changes with respect to volatile acidity

# %%
plt.figure(figsize=(12,7))
sns.violinplot(x='quality',y='volatile acidity',data=df,hue='quality')
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x='quality',y='volatile acidity',data=df,hue='quality')
plt.show()

# %% [markdown]
# ### The below plot explians in detail about how the density of wine varies with the fixed acidity

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x='density',y='fixed acidity',data=df)
# Out:
# <AxesSubplot:xlabel='density', ylabel='fixed acidity'>

# %% [markdown]
# ### The below plot explains about how volatile acidity of wine changes with respect to citric acid

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x='volatile acidity',y='citric acid',data=df)
plt.show()

# %% [markdown]
# ### The below plot explains how quality of wine varies in according with sulphates in it

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x='quality',y='sulphates',data=df,hue='quality')
plt.show()

# %% [markdown]
# ### The below plot describes about citric acid and volatile acidity

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x='citric acid',y='volatile acidity',data=df)
plt.show()

# %% [markdown]
# ### Splitting the dataset as 20% for testing and 80% for training

# %%
for col in ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol']:
    df[col]=df[col]/df[col].max()

# %%
feature=np.array(df[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol']])
label=np.array(df['quality'])

xtrain,xtest,ytrain,ytest=train_test_split(feature,label,test_size=0.2,random_state=0)

# %% [markdown]
# Preparing for Models

# %%
model_comp={}

# %% [markdown]
# ## LOGISTIC REGRESSION

# %%
lgr=LogisticRegression()
lgr.fit(xtrain,ytrain)
y1=lgr.predict(xtest)
print(accuracy_score(ytest,y1))
print(f1_score(ytest,y1,average='weighted'))
print(classification_report(ytest,y1))

model_comp['logistic regression']=[accuracy_score(y1,ytest),f1_score(ytest,y1,average='weighted')]
# Out:
# 0.6375545851528385
# 0.5818306114188381
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         7
#            5       0.69      0.82      0.75       100
#            6       0.58      0.70      0.63        92
#            7       0.00      0.00      0.00        27
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.64       229
#    macro avg       0.21      0.25      0.23       229
# weighted avg       0.54      0.64      0.58       229

# %% [markdown]
# ## DECISION TREE

# %%
dt=DecisionTreeClassifier()
dt.fit(xtrain,ytrain)
y2=dt.predict(xtest)

print(accuracy_score(ytest,y2))
print(f1_score(ytest,y2,average='weighted'))
print(classification_report(ytest,y2))

model_comp['decision tree']=[accuracy_score(y2,ytest),f1_score(ytest,y2,average='weighted')]
# Out:
# 0.5938864628820961
# 0.5962699357895865
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         7
#            5       0.68      0.67      0.68       100
#            6       0.60      0.60      0.60        92
#            7       0.45      0.48      0.46        27
#            8       1.00      0.50      0.67         2
#
#     accuracy                           0.59       229
#    macro avg       0.45      0.37      0.40       229
# weighted avg       0.60      0.59      0.60       229

# %% [markdown]
# ## RANDOM FOREST

# %%
rf=RandomForestClassifier()
rf.fit(xtrain,ytrain)
y3=rf.predict(xtest)

print(accuracy_score(ytest,y3))
print(f1_score(ytest,y3,average='weighted'))
print(classification_report(ytest,y3))


model_comp['Random forest']=[accuracy_score(y3,ytest),f1_score(ytest,y3,average='weighted')]
# Out:
# 0.6637554585152838
# 0.6486765662318073
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         7
#            5       0.72      0.78      0.75       100
#            6       0.62      0.65      0.64        92
#            7       0.58      0.52      0.55        27
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.66       229
#    macro avg       0.32      0.33      0.32       229
# weighted avg       0.64      0.66      0.65       229

# %% [markdown]
# ## KNN

# %%
k=KNeighborsClassifier()
k.fit(xtrain,ytrain)
y4=k.predict(xtest)

print(accuracy_score(ytest,y4))
print(f1_score(ytest,y4,average='weighted'))
print(classification_report(ytest,y4))

model_comp['KNN']=[accuracy_score(y4,ytest),f1_score(ytest,y4,average='weighted')]
# Out:
# 0.5589519650655022
# 0.5395476430410928
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         7
#            5       0.64      0.69      0.66       100
#            6       0.51      0.58      0.54        92
#            7       0.33      0.22      0.27        27
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.56       229
#    macro avg       0.25      0.25      0.25       229
# weighted avg       0.53      0.56      0.54       229

# %% [markdown]
# ## SVC

# %%
s=SVC()
s.fit(xtrain,ytrain)
y5=s.predict(xtest)

print(accuracy_score(ytest,y5))
print(f1_score(ytest,y5,average='weighted'))
print(classification_report(ytest,y5))

model_comp['svc']=[accuracy_score(y5,ytest),f1_score(ytest,y5,average='weighted')]
# Out:
# 0.6637554585152838
# 0.6069291484469779
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         7
#            5       0.73      0.81      0.77       100
#            6       0.60      0.77      0.68        92
#            7       0.00      0.00      0.00        27
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.66       229
#    macro avg       0.22      0.26      0.24       229
# weighted avg       0.56      0.66      0.61       229

# %% [markdown]
# ## Model Comparison

# %%
df1=pd.DataFrame.from_dict(model_comp).T
df1.columns=['Accuracy','F1_score']
df1=df1.sort_values('F1_score',ascending=True)
df1.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_3e57f_row0_col0, #T_3e57f_row0_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_3e57f_row1_col0 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_3e57f_row1_col1 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_3e57f_row2_col0 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_3e57f_row2_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_3e57f_row3_col0, #T_3e57f_row4_col0, #T_3e57f_row4_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_3e57f_row3_col1 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3e57f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e57f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_3e57f_level0_col1" class="col_heading level0 col1" >F1_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e57f_level0_row0" class="row_heading level0 row0" >KNN</th>
#       <td id="T_3e57f_row0_col0" class="data row0 col0" >0.558952</td>
#       <td id="T_3e57f_row0_col1" class="data row0 col1" >0.539548</td>
#     </tr>
#     <tr>
#       <th id="T_3e57f_level0_row1" class="row_heading level0 row1" >logistic regression</th>
#       <td id="T_3e57f_row1_col0" class="data row1 col0" >0.637555</td>
#       <td id="T_3e57f_row1_col1" class="data row1 col1" >0.581831</td>
#     </tr>
#     <tr>
#       <th id="T_3e57f_level0_row2" class="row_heading level0 row2" >decision tree</th>
#       <td id="T_3e57f_row2_col0" class="data row2 col0" >0.593886</td>
#       <td id="T_3e57f_row2_col1" class="data row2 col1" >0.596270</td>
#     </tr>
#     <tr>
#       <th id="T_3e57f_level0_row3" class="row_heading level0 row3" >svc</th>
#       <td id="T_3e57f_row3_col0" class="data row3 col0" >0.663755</td>
#       <td id="T_3e57f_row3_col1" class="data row3 col1" >0.606929</td>
#     </tr>
#     <tr>
#       <th id="T_3e57f_level0_row4" class="row_heading level0 row4" >Random forest</th>
#       <td id="T_3e57f_row4_col0" class="data row4 col0" >0.663755</td>
#       <td id="T_3e57f_row4_col1" class="data row4 col1" >0.648677</td>
#     </tr>
#   </tbody>
# </table>
